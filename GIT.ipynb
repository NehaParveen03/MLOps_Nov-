# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaParveen03/MLOps_Nov-/blob/main/GIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
what is version control ?
version control is a system that tracks changes to files over time so you can:
see who chnaged and what
go back to erlier version
helps in teamwork without overwritten any work

# %%
real world analogy:
project.docx
project_final.docx
project_final_v3.docx

# %%
key benefits of version control:
check complete history of cnages
easy rollback
team collaboration

# %%
what is Git?
it is a distributed version control system
linus torvalds in 2005

ex:
every developer has:
1.full copy of the code/project
2.full histroy
3.can work offline


types of version control system:
1.distributed
2.local
3.centralized == one central server

NOte: distributed is faster than centralized

# %%
to work with git :
1.git == tool/application that we will be using to work with github

2.github == its online cloud server/platform where your projects are going to store

# %%
to link your github to local git :
git config --global user.name "github username"
git config --global user.email "github email"
git config --list

# %%
repository == its a place where all your project files and history are stored and managed
. its stroes your code files
. it tracks every chnaged
. remembers who chnaged what and when

# %%
mkdir <folder_name> == to create a folder/directory
cd <folder_name> == to inside the the folder

# %%
git init== to initalizie a git repository(turn a folder into repo.)

# %%
to create a file:
touch <filename.txt>
nano filename.txt
write the content
ctrl+o , enter, ctrl+x

# %%
STAGED THE FILE
git add <filename>
git add . == top stage all the changes at the same time

# %%
commit the file
git commit -m "any meaasge"

# %%
to check commit history
git log
