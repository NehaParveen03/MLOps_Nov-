# %%
Python
|->Programming Language
     |=> download python from https://www.python.org = CPython - we can do python programming 
                                                       --------
     Python - everything is a class object design model
              ..........
               10 <== is an object - belongs to int class
               'ab' <== is an object - belongs to str class
              10.0 <== floating object - float class
               True /False <== bool class
     containers 
        - list tuple dict set
          ===============

    |-> download python from https://www.anaconda.com/download 
                            ---------------------------------
                we can do python + DataScience + ML modules - available

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
i = 10
j = 4+6
k = 2+8
l = 3+7

print(hex(id(i)))
print(hex(id(j)))
print(hex(id(k)))
print(hex(id(l)))
# Out:
# 0x7ffe10f3b4c8
# 0x7ffe10f3b4c8
# 0x7ffe10f3b4c8
# 0x7ffe10f3b4c8

# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %%
product
 |-> productID       - 101       = int    => product_id = 101
 |-> productName     - 'pA'      = str    => product_name = 'pA'
 |-> productCost     - 1000.32   = float  => product_cost = 1000.32
 |-> productSales    - True      = bool   => product_Sales = True
Vs
product_info1 = [101,'pA',1000.32,True] <== list - Collection of different types of items - mutable 
                                                 - we can add/modify/delete
Vs
product_info2 = (101,'pA',1000.32,True) <== tuple - Collection of different types of items - immutable
                                                  - we can't add/modify/delete

Vs
product_info3 = {'pid':101,'pname':'pA','pcost':1000.32,'pstatus':True} <== dict
                - Collection of different types of items - mutable
                - - we can add/modify/delete

# %%
# Given List 
product_info1 = [101,'pA',1000.32,True]

print(type(product_info1))
# Out:
# <class 'list'>

# %%
print(product_info1[0])
print(product_info1[1])
print(product_info1[-1])
# Out:
# 101
# pA
# True

# %%
product_info1[2]
# Out:
# 1000.32

# %%
# To modify
product_info1[2] = 4590.32

# %%
print(product_info1)
# Out:
# [101, 'pA', 4590.32, True]

# %%
# tuple - record 
product_info2 = (101,'pA',1000.32,True) # immutable
print(type(product_info2))
# Out:
# <class 'tuple'>

# %%
product_info2
# Out:
# (101, 'pA', 1000.32, True)

# %%
product_info2[0]
# Out:
# 101

# %%
product_info2[-1]
# Out:
# True

# %%
product_info3 = {'pid':101,'pname':'pA','pcost':1000.32,'pstatus':True}
print(type(product_info3))
# Out:
# <class 'dict'>

# %%
product_info3['pid']
# Out:
# 101

# %%
product_info3['pcost']
# Out:
# 1000.32

# %%
product_info3['pcost'] = 5689.42 # we can modify an existing value

# %%
product_info3
# Out:
# {'pid': 101, 'pname': 'pA', 'pcost': 5689.42, 'pstatus': True}

# %%
list,dict - mutable 

list,dict
...................................
list of list  => [ [],[],[],[] ]
list of dict  => [ {},{},{},{} ] 
dict of list  => { 'key1': [], 'key2':[] ... 'Kn':[] } <=== 
dict of dict  => { 'Key1': {} , 'Key2':{} }
...................................

# %%
# list of list
product_list = [[101,'pA',1000],[102,'pB',2000],[103,'pC',3000]]
product_list
# Out:
# [[101, 'pA', 1000], [102, 'pB', 2000], [103, 'pC', 3000]]

# %%
product_list.append([104,'pD',3450])
product_list
# Out:
# [[101, 'pA', 1000], [102, 'pB', 2000], [103, 'pC', 3000], [104, 'pD', 3450]]

# %%
print(product_list[0])
print(product_list[1])
# Out:
# [101, 'pA', 1000]
# [102, 'pB', 2000]

# %%
print(product_list[1][0])
# Out:
# 102

# %%
# list of dict
product_list = [{'pid':101,'pname':'pA','pcost':1000},
                {'pid':102,'pname':'pB','pcost':2000},
                {'pid':103,'pname':'pC','pcost':3000}
               ]

# %%
product_list[0]
# Out:
# {'pid': 101, 'pname': 'pA', 'pcost': 1000}

# %%
product_list[0]['pname'] # list of dict
# Out:
# 'pA'

# %%
L = [["D1","D2","D3"],{"K1":"D4","K2":"D5"}]
L
# Out:
# [['D1', 'D2', 'D3'], {'K1': 'D4', 'K2': 'D5'}]

# %%
# Create a product list - productName,productID,productCost
# -----------------------
# dict of list => d={'Key1':[]}
#
# dict of dict => d={'Key1':{}}

# %%
products = {}

products['pid'] = []
products['pname'] = []
products['pcost'] = []
products
# Out:
# {'pid': [], 'pname': [], 'pcost': []}

# %%
products['pid'].append(101)
products['pname'].append('pA')
products['pcost'].append(1000)
products
# Out:
# {'pid': [101], 'pname': ['pA'], 'pcost': [1000]}

# %%
products['pid'].append(102)
products['pname'].append('pB')
products['pcost'].append(2000)
products['pid'].append(103)
products['pname'].append('pC')
products['pcost'].append(3000)

# %%
products
# Out:
# {'pid': [101, 102, 103],
#  'pname': ['pA', 'pB', 'pC'],
#  'pcost': [1000, 2000, 3000]}

# %%
# dict of dict

products={}
products['K1']={'pid':101,'pname':'pA','pcost':1000}
products['K2']={'pid':102,'pname':'pB','pcost':2000}
products['K3']={'pid':103,'pname':'pC','pcost':3000}
products['K4']={'pid':104,'pname':'pD','pcost':4000}
products
# Out:
# {'K1': {'pid': 101, 'pname': 'pA', 'pcost': 1000},
#  'K2': {'pid': 102, 'pname': 'pB', 'pcost': 2000},
#  'K3': {'pid': 103, 'pname': 'pC', 'pcost': 3000},
#  'K4': {'pid': 104, 'pname': 'pD', 'pcost': 4000}}

# %%
products['K1']
# Out:
# {'pid': 101, 'pname': 'pA', 'pcost': 1000}

# %%
products['K1']['pname']
# Out:
# 'pA'

# %%
[
  {
    "login": "ggobi",
    "id": 423638,
    "node_id": "MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==",
    "url": "https://api.github.com/orgs/ggobi",
    "repos_url": "https://api.github.com/orgs/ggobi/repos",
    "events_url": "https://api.github.com/orgs/ggobi/events",
    "hooks_url": "https://api.github.com/orgs/ggobi/hooks",
    "issues_url": "https://api.github.com/orgs/ggobi/issues",
    "members_url": "https://api.github.com/orgs/ggobi/members{/member}",
    "public_members_url": "https://api.github.com/orgs/ggobi/public_members{/member}",
    "avatar_url": "https://avatars.githubusercontent.com/u/423638?v=4",
    "description": ""
  }
]

# %%
numpy   - Computation
  |-> index , slicing , reshaping
  |-> ufunctions 

pandas  - Analysis
  |-> Series
  |-> DataFrame 

matplotlib - Visualization
 |-> plot,scatter,bar,pie,....

# %%
L=[10,20,30,40,50]
L+100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 L=[10,20,30,40,50]
# ----> 2 L+100
#
# TypeError: can only concatenate list (not "int") to list

# %%
import numpy
numpy.array([])
# Out:
# array([], dtype=float64)

# %%
import numpy as np
np.array([])
# Out:
# array([], dtype=float64)

# %%
arr = np.array([10,20,30,40,50])
arr+100
# Out:
# array([110, 120, 130, 140, 150])

# %%
arr+100.56
# Out:
# array([110.56, 120.56, 130.56, 140.56, 150.56])

# %%
print(arr)
print(arr.dtype)
print(arr.shape)
print(arr.ndim)
# Out:
# [10 20 30 40 50]
# int64
# (5,)
# 1

# %%
print(np.array([10,20,30]).dtype)
print(np.array([10,20,30.0]).dtype)
print(np.array([10,20,True]).dtype)
print(np.array([True,False]).dtype)
print(np.array([10,20,3.5,True]).dtype)
print('')
print(np.array([10,20,'data']).dtype)
# Out:
# int64
# float64
# int64
# bool
# float64
#
# <U21

# %%
np.array([10,20,30])+100
# Out:
# array([110, 120, 130])

# %%
np.array([10,20,'data'])+100
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 np.array([10,20,'data'])+100
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U21'), dtype('int64')) -> None

# %%
np.array([10,20,30]).ndim
# Out:
# 1

# %%
np.array([[10,20,30]]).ndim
# Out:
# 2

# %%
arr = np.array([[10,20,30]])
arr.ndim
# Out:
# 2

# %%
arr
# Out:
# array([[10, 20, 30]])

# %%
arr[0]
# Out:
# array([10, 20, 30])

# %%
arr[0][0]
# Out:
# np.int64(10)

# %%
arr = np.array([[10,20,30],[40,50,60]])
print(arr.ndim,arr.shape)
print(arr)
# Out:
# 2 (2, 3)
# [[10 20 30]
#  [40 50 60]]

# %%
      C1  C2   C3  
row1 10 | 20 | 30
     ---|----|--
row2 40 |50  |60

# %%
arr.reshape(3,2)
# Out:
# array([[10, 20],
#        [30, 40],
#        [50, 60]])

# %%
arr.reshape(1,6)
# Out:
# array([[10, 20, 30, 40, 50, 60]])

# %%
arr.reshape(6,1)
# Out:
# array([[10],
#        [20],
#        [30],
#        [40],
#        [50],
#        [60]])

# %%
arr.reshape(2,3)
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
arr.reshape(-1,1) # Convert to 2D
# Out:
# array([[10],
#        [20],
#        [30],
#        [40],
#        [50],
#        [60]])

# %%
# numpy universal functions
# ----------------------------
np.mean() => np.mean(data) 
np.median() =>np.median(data) 
np.std() -> np.std(data)
np.max(data)
np.min(data)
np.sum(data) - sum of all items

# %%
# Python way - Calculate sum of given list

L=[10,20,30,40,50]

total = 0
for var in L:
    total = total + var
print(total)

## Vs
# numpy 
arr = np.array(L)
print(np.sum(arr))
# Out:
# 150
# 150

# %%
np.mean(arr)
# Out:
# np.float64(30.0)

# %%
np.median(arr)
# Out:
# np.float64(30.0)

# %%
arr = np.array([[1,2,3],[4,5,6]])

print(np.mean(arr))
# Out:
# 3.5

# %%
   |  |    |  <== Column = axis=0
--------->--------------
           Row = axis = 1

# %%
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.mean(arr,axis=1) # row
# Out:
# array([2., 5.])

# %%
np.mean(arr,axis=0) # column
# Out:
# array([2.5, 3.5, 4.5])

# %%
products = {'pid':[],'pname':[],'pcost':[]}
products['pid'].append(101)
products['pname'].append('pA')
products['pcost'].append(1000)
products
# Out:
# {'pid': [101], 'pname': ['pA'], 'pcost': [1000]}

# %%
products['pid'].append(102)
products['pname'].append('pB')
products['pcost'].append(2000)
products['pid'].append(103)
products['pname'].append('pC')
products['pcost'].append(3000)
products['pid'].append(104)
products['pname'].append('pD')
products['pcost'].append(4000)

# %%
products
# Out:
# {'pid': [101, 102, 103, 104],
#  'pname': ['pA', 'pB', 'pC', 'pD'],
#  'pcost': [1000, 2000, 3000, 4000]}

# %%
print(type(products))
# Out:
# <class 'dict'>

# %%
products['pcost']
# Out:
# [1000, 2000, 3000, 4000]

# %%
arr = np.array(products['pcost']) # ->numpy_array_object
np.sum(arr)
# Out:
# np.int64(10000)

# %%
np.max(arr)
# Out:
# np.int64(4000)

# %%
np.mean(arr)
# Out:
# np.float64(2500.0)

# %%
###################################################

# %%
import pandas
pandas
# Out:
# <module 'pandas' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
print(pandas.Series)
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(pandas.DataFrame)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
pandas/
   |___core/
        |__frame.py
               |__class DataFrame:

# %%
import pandas as pd
pd.Series([10,20,30,40,50])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.DataFrame([10,20,30,40,50])
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
products = {}
products['pid'] = [101,102,103]
products['pname'] = ['pA','pB','pC']
products['pcost'] = [1000,2000,3000]
products
# Out:
# {'pid': [101, 102, 103],
#  'pname': ['pA', 'pB', 'pC'],
#  'pcost': [1000, 2000, 3000]}

# %%
pd.DataFrame(products)
# Out:
#    pid pname  pcost
# 0  101    pA   1000
# 1  102    pB   2000
# 2  103    pC   3000

# %%
df1 = pd.DataFrame(products)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     3 non-null      int64
#  1   pname   3 non-null      object
#  2   pcost   3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1.columns
# Out:
# Index(['pid', 'pname', 'pcost'], dtype='object')

# %%
# To fetch data - row based => df.loc[index] -> record 
#
# To fetch data - column based -> df['ColumnName'] -> column
#                                 -like dictName['key']

# %%
df1.loc[1]
# Out:
# pid       102
# pname      pB
# pcost    2000
# Name: 1, dtype: object

# %%
df1.loc[0]
# Out:
# pid       101
# pname      pA
# pcost    1000
# Name: 0, dtype: object

# %%
df1.loc[1]
# Out:
# pid       102
# pname      pB
# pcost    2000
# Name: 1, dtype: object

# %%
df1['pid']
# Out:
# 0    101
# 1    102
# 2    103
# Name: pid, dtype: int64

# %%
df1['pname']
# Out:
# 0    pA
# 1    pB
# 2    pC
# Name: pname, dtype: object

# %%
df1.loc[1]['pname']
# Out:
# 'pB'

# %%
# add more products to product_structure(dict) - do append operation
# |->initialize to DataFrame ->new_df 
#                                 |->Fetch Row X Column

# %%
products = {}
products['pid'] = [101,102,103]
products['pname'] = ['pA','pB','pC']
products['pcost'] = [1000,2000,3000]

# %%
products['pid'].append(104)
products['pname'].append('pD')
products['pcost'].append(4000)

products['pid'].append(105)
products['pname'].append('pE')
products['pcost'].append(5000)

products['pid'].append(106)
products['pname'].append('pF')
products['pcost'].append(6000)

products['pid'].append(107)
products['pname'].append('pG')
products['pcost'].append(2300)

products['pid'].append(108)
products['pname'].append('pH')
products['pcost'].append(3400)

# %%
df2 = pd.DataFrame(products)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     8 non-null      int64
#  1   pname   8 non-null      object
#  2   pcost   8 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 324.0+ bytes

# %%
df2['pid']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# Name: pid, dtype: int64

# %%
df2.loc[2]
# Out:
# pid       103
# pname      pC
# pcost    3000
# Name: 2, dtype: object

# %%
df2.loc[2:] # from 2nd row to list of all - Slicing
# Out:
#    pid pname  pcost
# 2  103    pC   3000
# 3  104    pD   4000
# 4  105    pE   5000
# 5  106    pF   6000
# 6  107    pG   2300
# 7  108    pH   3400

# %%
df2.loc[2:5] # from 2nd row - 5th row
# Out:
#    pid pname  pcost
# 2  103    pC   3000
# 3  104    pD   4000
# 4  105    pE   5000
# 5  106    pF   6000

# %%
df2.loc[3]['pname']
# Out:
# 'pD'

# %%
df2.loc[3][['pname','pcost']]
# Out:
# pname      pD
# pcost    4000
# Name: 3, dtype: object

# %%
df2.loc[2:5][['pname','pcost']] # from 2nd row - 5th row - filter productName,productCost
# Out:
#   pname  pcost
# 2    pC   3000
# 3    pD   4000
# 4    pE   5000
# 5    pF   6000

# %%
df2['pcost']
df2['pcost'] * 0.18
# Out:
# 0     180.0
# 1     360.0
# 2     540.0
# 3     720.0
# 4     900.0
# 5    1080.0
# 6     414.0
# 7     612.0
# Name: pcost, dtype: float64

# %%
df2['pcost'] >3000
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# Name: pcost, dtype: bool

# %%
df2[df2['pcost'] >3000] # boolean index - filter True values/records only
# Out:
#    pid pname  pcost
# 3  104    pD   4000
# 4  105    pE   5000
# 5  106    pF   6000
# 7  108    pH   3400

# %%
# In pandas DataFrame - mutable - inplace=True <== modified input DataFrame

# %%
# To delete a particular row/record 
# df.drop(rowIndex)
len(df2.index)
# Out:
# 8

# %%
df2.drop(3) # delete 3rd row
# Out:
#    pid pname  pcost
# 0  101    pA   1000
# 1  102    pB   2000
# 2  103    pC   3000
# 4  105    pE   5000
# 5  106    pF   6000
# 6  107    pG   2300
# 7  108    pH   3400

# %%
len(df2.index)
# Out:
# 8

# %%
df2
# Out:
#    pid pname  pcost
# 0  101    pA   1000
# 1  102    pB   2000
# 2  103    pC   3000
# 3  104    pD   4000
# 4  105    pE   5000
# 5  106    pF   6000
# 6  107    pG   2300
# 7  108    pH   3400

# %%
df3 = df2.drop(3)
print(len(df3.index))
print(len(df2.index))
# Out:
# 7
# 8

# %%
df2.drop(4,inplace=True) # ->None. But dataframe is updated

# %%
len(df2.index)
# Out:
# 7

# %%
df2
# Out:
#    pid pname  pcost
# 0  101    pA   1000
# 1  102    pB   2000
# 2  103    pC   3000
# 3  104    pD   4000
# 5  106    pF   6000
# 6  107    pG   2300
# 7  108    pH   3400

# %%
########
